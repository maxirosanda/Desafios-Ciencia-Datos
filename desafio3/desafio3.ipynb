# %%
import pandas as pd
import numpy as np
Summer_Olympic_medals = pd.read_csv('./Summer-Olympic-medals-1976-to-2008.csv')

"""indice = list(Summer_Olympic_medals.Year)
indice = np.array(indice).astype(int)
columnas = Summer_Olympic_medals.columns[2:]
valores =Summer_Olympic_medals.values[:,2:]
Summer_Olympic_medals = pd.DataFrame(valores,index=indice,columns=columnas)"""
Summer_Olympic_medals = pd.Series(Summer_Olympic_medals['City'])
Summer_Olympic_medals
# Out:
# 0        Montreal
# 1        Montreal
# 2        Montreal
# 3        Montreal
# 4        Montreal
#            ...
# 15428     Beijing
# 15429     Beijing
# 15430     Beijing
# 15431     Beijing
# 15432     Beijing
# Name: City, Length: 15433, dtype: object
