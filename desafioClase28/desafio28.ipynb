# %%
import pandas as pd
import numpy as np 
  
df_w = pd.read_csv("w_data.csv", encoding = "UTF-8", delimiter = ";")
df_p = pd.read_csv("p_data.csv", encoding = "UTF-8", delimiter = ";")
left_join = pd.merge(df_w, df_p, how='left', on='ID')
left_join = left_join.set_index('ID')
#left_join['Target'] = left_join['Target'].map({'<=50K.':'<=50K','>50K.':'>50K'},na_action=None) #no puedo remplazar los valores
#dummies = pd.get_dummies(left_join["Target"])
left_join
# Out:
#                     Workclass    fnlwgt  Capital Gain  Capital Loss  \
# ID
# 49084               State-gov   77516.0        2174.0           0.0
# 68553        Self-emp-not-inc   83311.0           0.0           0.0
# 143654                Private  215646.0           0.0           0.0
# 41510                 Private  234721.0           0.0           0.0
# 195025                Private  338409.0           0.0           0.0
# ...                       ...       ...           ...           ...
# 735617153             Private  215419.0           0.0           0.0
# 1131807446                  ?  321403.0           0.0           0.0
# 781422087             Private  374983.0           0.0           0.0
# 161771296             Private   83891.0        5455.0           0.0
# 1344995623       Self-emp-inc  182148.0           0.0           0.0
#
#             Hours per week Target   Age      Sex                 Race  \
# ID
# ...
